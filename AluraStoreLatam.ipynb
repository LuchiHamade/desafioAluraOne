# %% [markdown]
# <a href="https://colab.research.google.com/github/LuchiHamade/desafioAluraOne/blob/main/AluraStoreLatam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"


tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

#tienda.head()

# Poder ver las cinco primeras filas de las tiendas para verificar que estén bien cargadas

for i, df in enumerate([tienda, tienda2, tienda3, tienda4], start=1):
    print(f"📦 Tienda {i}:")
    display(df.head())
    print("\n")  # espacio entre tablas
# Out:
# 📦 Tienda 1:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# 1  Tarjeta de crédito                   4   6.25184 -75.56359
# 2  Tarjeta de crédito                   1  10.39972 -75.51444
# 3               Nequi                   1   3.43722 -76.52250
# 4               Nequi                   1   6.25184 -75.56359
# 📦 Tienda 2:
#            Producto  Categoría del Producto    Precio  Costo de envío  \
# 0  Silla de oficina                 Muebles  283600.0         15300.0
# 1         Pandereta  Instrumentos musicales   76800.0          2300.0
# 2         Cama king                 Muebles  443300.0         23800.0
# 3         Cama king                 Muebles  906200.0         46400.0
# 4  Silla de oficina                 Muebles  397800.0         19400.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      04/08/2021  Izabela de León        Medellín             1
# 1      26/11/2020   Blanca Ramirez        Medellín             3
# 2      22/10/2021  Izabela de León         Pereira             5
# 3      04/05/2022    Maria Alfonso            Cali             5
# 4      26/02/2022    Lucas Olivera          Bogotá             4
#
#        Método de pago  Cantidad de cuotas      lat       lon
# 0               Nequi                   1  6.25184 -75.56359
# 1  Tarjeta de crédito                   4  6.25184 -75.56359
# 2  Tarjeta de crédito                  10  4.81333 -75.69611
# 3  Tarjeta de crédito                  10  3.43722 -76.52250
# 4  Tarjeta de crédito                   3  4.60971 -74.08175
# 📦 Tienda 3:
#             Producto  Categoría del Producto     Precio  Costo de envío  \
# 0   Secadora de ropa       Electrodomésticos  1285100.0         66600.0
# 1      Mesa de noche                 Muebles   290100.0         13600.0
# 2  Guitarra acústica  Instrumentos musicales   303500.0         17400.0
# 3  Balón de voleibol    Deportes y diversión    58800.0          3300.0
# 4            Armario                 Muebles   521100.0         25900.0
#
#   Fecha de Compra        Vendedor Lugar de Compra  Calificación  \
# 0      17/12/2021   Camila Rivera     Santa Marta             4
# 1      10/02/2021   Maria Alfonso            Cali             3
# 2      22/01/2023   Lucas Olivera          Bogotá             5
# 3      22/03/2022     Pedro Gomez    Barranquilla             4
# 4      12/01/2022  Blanca Ramirez          Bogotá             1
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   4  11.24079 -74.19904
# 1  Tarjeta de crédito                   1   3.43722 -76.52250
# 2  Tarjeta de crédito                   3   4.60971 -74.08175
# 3  Tarjeta de crédito                   6  10.96854 -74.78132
# 4  Tarjeta de crédito                   1   4.60971 -74.08175
# 📦 Tienda 4:
#               Producto Categoría del Producto     Precio  Costo de envío  \
# 0         Lavavajillas      Electrodomésticos  1084800.0         56000.0
# 1             Cama box                Muebles   473800.0         25400.0
# 2  Balón de baloncesto   Deportes y diversión    23700.0             0.0
# 3  Modelado predictivo                 Libros    57700.0          1300.0
# 4          Auriculares           Electrónicos   138900.0          5600.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      11/11/2022    Rafael Acosta          Bogotá             4
# 1      03/01/2020  Izabela de León          Cúcuta             5
# 2      25/12/2022    Maria Alfonso        Medellín             5
# 3      23/11/2021    Lucas Olivera        Medellín             3
# 4      25/04/2022   Blanca Ramirez          Bogotá             4
#
#        Método de pago  Cantidad de cuotas      lat       lon
# 0  Tarjeta de crédito                   3  4.60971 -74.08175
# 1  Tarjeta de crédito                   2  7.89391 -72.50782
# 2               Nequi                   1  6.25184 -75.56359
# 3               Nequi                   1  6.25184 -75.56359
# 4  Tarjeta de crédito                   7  4.60971 -74.08175

# %% [markdown]
# #1. Análisis de facturación

# %%
# Calcular ingresos por tienda
ingreso_t1 = tienda["Precio"].sum()
ingreso_t2 = tienda2["Precio"].sum()
ingreso_t3 = tienda3["Precio"].sum()
ingreso_t4 = tienda4["Precio"].sum()

# Creación diccionario ingresos por tienda
ingresos_dict = {
    "Tienda 1": ingreso_t1,
    "Tienda 2": ingreso_t2,
    "Tienda 3": ingreso_t3,
    "Tienda 4": ingreso_t4
}


# Mostrar resultados
print(f" Ingreso total Tienda 1: ${ingreso_t1:,.2f}")
print(f"Ingreso total Tienda 2: ${ingreso_t2:,.2f}")
print(f" Ingreso total Tienda 3: ${ingreso_t3:,.2f}")
print(f"Ingreso total Tienda 4: ${ingreso_t4:,.2f}")



df_ingresos = pd.DataFrame({
    "Tienda": ingresos_dict.keys(),
    "Ingreso Total (sin formato)": ingresos_dict.values()
})

# Crear nueva columna con un formato más legible
df_ingresos["Ingreso Total"] = df_ingresos["Ingreso Total (sin formato)"].apply(lambda x: f"${x:,.2f}")

# Mostrar tabla de ingresos
display(df_ingresos[["Tienda", "Ingreso Total"]])
# Out:
#  Ingreso total Tienda 1: $1,150,880,400.00
# Ingreso total Tienda 2: $1,116,343,500.00
#  Ingreso total Tienda 3: $1,098,019,600.00
# Ingreso total Tienda 4: $1,038,375,700.00
#      Tienda      Ingreso Total
# 0  Tienda 1  $1,150,880,400.00
# 1  Tienda 2  $1,116,343,500.00
# 2  Tienda 3  $1,098,019,600.00
# 3  Tienda 4  $1,038,375,700.00

# %% [markdown]
# # 2. Ventas por categoría

# %%
# Agregar la columna 'tienda' a cada DataFrame individual
tienda["tienda"] = "Tienda_1"
tienda2["tienda"] = "Tienda_2"
tienda3["tienda"] = "Tienda_3"
tienda4["tienda"] = "Tienda_4"


# Combinar
datos_tiendas = pd.concat([tienda, tienda2, tienda3, tienda4], ignore_index=True)

# Limpiar columnas
datos_tiendas.columns = datos_tiendas.columns.str.strip().str.lower().str.replace(" ", "_")

# Imprimir la columna tienda
print(datos_tiendas["tienda"].head())

# Agrupar por tienda y categoría
ventas_por_categoria = datos_tiendas.groupby(['tienda', 'categoría_del_producto']).size().reset_index(name='cantidad_ventas')

# 6. Ordenar para ver las categorías más populares por tienda (opcional)
ventas_por_categoria = ventas_por_categoria.sort_values(['tienda', 'cantidad_ventas'], ascending=[True, False])

# 7. Mostrar resultado
display(ventas_por_categoria)
# Out:
# 0    Tienda_1
# 1    Tienda_1
# 2    Tienda_1
# 3    Tienda_1
# 4    Tienda_1
# Name: tienda, dtype: object
#       tienda   categoría_del_producto  cantidad_ventas
# 7   Tienda_1                  Muebles              465
# 3   Tienda_1             Electrónicos              448
# 5   Tienda_1                 Juguetes              324
# 2   Tienda_1        Electrodomésticos              312
# 1   Tienda_1     Deportes y diversión              284
# 4   Tienda_1   Instrumentos musicales              182
# 6   Tienda_1                   Libros              173
# 0   Tienda_1  Artículos para el hogar              171
# 15  Tienda_2                  Muebles              442
# 11  Tienda_2             Electrónicos              422
# 13  Tienda_2                 Juguetes              313
# 10  Tienda_2        Electrodomésticos              305
# 9   Tienda_2     Deportes y diversión              275
# 12  Tienda_2   Instrumentos musicales              224
# 14  Tienda_2                   Libros              197
# 8   Tienda_2  Artículos para el hogar              181
# 23  Tienda_3                  Muebles              499
# 19  Tienda_3             Electrónicos              451
# 21  Tienda_3                 Juguetes              315
# 18  Tienda_3        Electrodomésticos              278
# 17  Tienda_3     Deportes y diversión              277
# 22  Tienda_3                   Libros              185
# 16  Tienda_3  Artículos para el hogar              177
# 20  Tienda_3   Instrumentos musicales              177
# 31  Tienda_4                  Muebles              480
# 27  Tienda_4             Electrónicos              451
# 29  Tienda_4                 Juguetes              338
# 25  Tienda_4     Deportes y diversión              277
# 26  Tienda_4        Electrodomésticos              254
# 24  Tienda_4  Artículos para el hogar              201
# 30  Tienda_4                   Libros              187
# 28  Tienda_4   Instrumentos musicales              170

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
# Calcular el promedio de calificación por tienda
calificaciones_promedio = (
    datos_tiendas
    .groupby("tienda")["calificación"]
    .mean()
    .reset_index(name="calificación_promedio")
    .sort_values("calificación_promedio", ascending=False)
)

# ✅ Formatear el promedio con 2 decimales
calificaciones_promedio["calificación_promedio"] = calificaciones_promedio["calificación_promedio"].round(2)

# ✅ Mostrar resultado
display(calificaciones_promedio)
# Out:
#      tienda  calificación_promedio
# 2  Tienda_3                   4.05
# 1  Tienda_2                   4.04
# 3  Tienda_4                   4.00
# 0  Tienda_1                   3.98

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
# Asumimos que cada fila representa 1 unidad vendida
df['Unidades'] = 1

# Agrupamos por tienda y producto, contando unidades vendidas
ventas = df.groupby(['Lugar de Compra', 'Producto'])['Unidades'].sum().reset_index()

# Producto más vendido por tienda
top = ventas.loc[ventas.groupby('Lugar de Compra')['Unidades'].idxmax()]
top['Tipo'] = 'Más vendido'

# Producto menos vendido por tienda
bottom = ventas.loc[ventas.groupby('Lugar de Compra')['Unidades'].idxmin()]
bottom['Tipo'] = 'Menos vendido'

# Unimos ambos en un solo DataFrame
resumen = pd.concat([top, bottom])

# %%
#visualización

import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
sns.barplot(data=resumen, x='Lugar de Compra', y='Unidades', hue='Tipo', palette='coolwarm')
plt.title('Productos más y menos vendidos por tienda')
plt.xlabel('Tienda')
plt.ylabel('Unidades vendidas')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
promedio_envio = df.groupby('Lugar de Compra')['Costo de envío'].mean().reset_index()
promedio_envio.columns = ['Lugar de Compra', 'Costo de Envío Promedio']

import seaborn as sns
import matplotlib.pyplot as plt

# Paleta rosa-púrpura personalizada según cantidad de tiendas
colores = sns.color_palette("rocket", n_colors=len(promedio_envio))

plt.figure(figsize=(12, 6))
sns.barplot(
    data=promedio_envio,
    x='Lugar de Compra',
    y='Costo de Envío Promedio',
    palette=colores,
    hue='Lugar de Compra',
    legend=False
)
plt.xticks(rotation=45)
plt.title('Costo de Envío Promedio por Tienda', fontsize=14)
plt.xlabel('Tienda')
plt.ylabel('Costo Promedio de Envío ($)')
plt.tight_layout()
plt.show()

# %%
# Ordenar la tabla de menor a mayor costo promedio
tabla_final = promedio_envio.sort_values(by='Costo de Envío Promedio', ascending=True)

# Mostrar la tabla
display(tabla_final.style.format({'Costo de Envío Promedio': '${:,.2f}'}))
# Out:
# <style type="text/css">
# </style>
# <table id="T_064ce" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_064ce_level0_col0" class="col_heading level0 col0" >Lugar de Compra</th>
#       <th id="T_064ce_level0_col1" class="col_heading level0 col1" >Costo de Envío Promedio</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_064ce_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_064ce_row0_col0" class="data row0 col0" >Armenia</td>
#       <td id="T_064ce_row0_col1" class="data row0 col1" >$4,566.67</td>
#     </tr>
#     <tr>
#       <th id="T_064ce_level0_row1" class="row_heading level0 row1" >9</th>
#       <td id="T_064ce_row1_col0" class="data row1 col0" >Manizales</td>
#       <td id="T_064ce_row1_col1" class="data row1 col1" >$11,366.67</td>
#     </tr>
#     <tr>
#       <th id="T_064ce_level0_row2" class="row_heading level0 row2" >6</th>
#       <td id="T_064ce_row2_col0" class="data row2 col0" >Cúcuta</td>
#       <td id="T_064ce_row2_col1" class="data row2 col1" >$12,331.25</td>
#     </tr>
#     <tr>
#       <th id="T_064ce_level0_row3" class="row_heading level0 row3" >18</th>
#       <td id="T_064ce_row3_col0" class="data row3 col0" >Villavicencio</td>
#       <td id="T_064ce_row3_col1" class="data row3 col1" >$12,914.29</td>
#     </tr>
#     <tr>
#       <th id="T_064ce_level0_row4" class="row_heading level0 row4" >17</th>
#       <td id="T_064ce_row4_col0" class="data row4 col0" >Valledupar</td>
#       <td id="T_064ce_row4_col1" class="data row4 col1" >$14,500.00</td>
#     </tr>
#     <tr>
#       <th id="T_064ce_level0_row5" class="row_heading level0 row5" >15</th>
#       <td id="T_064ce_row5_col0" class="data row5 col0" >Santa Marta</td>
#       <td id="T_064ce_row5_col1" class="data row5 col1" >$20,045.71</td>
#     </tr>
#     <tr>
#       <th id="T_064ce_level0_row6" class="row_heading level0 row6" >5</th>
#       <td id="T_064ce_row6_col0" class="data row6 col0" >Cartagena</td>
#       <td id="T_064ce_row6_col1" class="data row6 col1" >$20,907.94</td>
#     </tr>
#     <tr>
#       <th id="T_064ce_level0_row7" class="row_heading level0 row7" >2</th>
#       <td id="T_064ce_row7_col0" class="data row7 col0" >Bogotá</td>
#       <td id="T_064ce_row7_col1" class="data row7 col1" >$22,519.78</td>
#     </tr>
#     <tr>
#       <th id="T_064ce_level0_row8" class="row_heading level0 row8" >1</th>
#       <td id="T_064ce_row8_col0" class="data row8 col0" >Barranquilla</td>
#       <td id="T_064ce_row8_col1" class="data row8 col1" >$23,016.25</td>
#     </tr>
#     <tr>
#       <th id="T_064ce_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_064ce_row9_col0" class="data row9 col0" >Medellín</td>
#       <td id="T_064ce_row9_col1" class="data row9 col1" >$23,256.67</td>
#     </tr>
#     <tr>
#       <th id="T_064ce_level0_row10" class="row_heading level0 row10" >12</th>
#       <td id="T_064ce_row10_col0" class="data row10 col0" >Pasto</td>
#       <td id="T_064ce_row10_col1" class="data row10 col1" >$25,710.00</td>
#     </tr>
#     <tr>
#       <th id="T_064ce_level0_row11" class="row_heading level0 row11" >8</th>
#       <td id="T_064ce_row11_col0" class="data row11 col0" >Leticia</td>
#       <td id="T_064ce_row11_col1" class="data row11 col1" >$26,174.29</td>
#     </tr>
#     <tr>
#       <th id="T_064ce_level0_row12" class="row_heading level0 row12" >4</th>
#       <td id="T_064ce_row12_col0" class="data row12 col0" >Cali</td>
#       <td id="T_064ce_row12_col1" class="data row12 col1" >$26,200.39</td>
#     </tr>
#     <tr>
#       <th id="T_064ce_level0_row13" class="row_heading level0 row13" >11</th>
#       <td id="T_064ce_row13_col0" class="data row13 col0" >Neiva</td>
#       <td id="T_064ce_row13_col1" class="data row13 col1" >$26,600.00</td>
#     </tr>
#     <tr>
#       <th id="T_064ce_level0_row14" class="row_heading level0 row14" >7</th>
#       <td id="T_064ce_row14_col0" class="data row14 col0" >Inírida</td>
#       <td id="T_064ce_row14_col1" class="data row14 col1" >$26,800.00</td>
#     </tr>
#     <tr>
#       <th id="T_064ce_level0_row15" class="row_heading level0 row15" >3</th>
#       <td id="T_064ce_row15_col0" class="data row15 col0" >Bucaramanga</td>
#       <td id="T_064ce_row15_col1" class="data row15 col1" >$27,410.00</td>
#     </tr>
#     <tr>
#       <th id="T_064ce_level0_row16" class="row_heading level0 row16" >13</th>
#       <td id="T_064ce_row16_col0" class="data row16 col0" >Pereira</td>
#       <td id="T_064ce_row16_col1" class="data row16 col1" >$27,626.23</td>
#     </tr>
#     <tr>
#       <th id="T_064ce_level0_row17" class="row_heading level0 row17" >14</th>
#       <td id="T_064ce_row17_col0" class="data row17 col0" >Riohacha</td>
#       <td id="T_064ce_row17_col1" class="data row17 col1" >$28,972.73</td>
#     </tr>
#     <tr>
#       <th id="T_064ce_level0_row18" class="row_heading level0 row18" >16</th>
#       <td id="T_064ce_row18_col0" class="data row18 col0" >Soacha</td>
#       <td id="T_064ce_row18_col1" class="data row18 col1" >$44,750.00</td>
#     </tr>
#   </tbody>
# </table>
