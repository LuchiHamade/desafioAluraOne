# %% [markdown]
# <a href="https://colab.research.google.com/github/LuchiHamade/desafioAluraOne/blob/main/AluraStoreLatam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"


tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

columnas_a_eliminar = ['lat', 'lon']

tienda = tienda.drop(columns=columnas_a_eliminar)
tienda2 = tienda2.drop(columns=columnas_a_eliminar)
tienda3 = tienda3.drop(columns=columnas_a_eliminar)
tienda4 = tienda4.drop(columns=columnas_a_eliminar)

#tienda.head()

# Poder ver las cinco primeras filas de las tiendas para verificar que estén bien cargadas

for i, df in enumerate([tienda, tienda2, tienda3, tienda4], start=1):
    print(f"📦 Tienda {i}:")
    display(df.head())
    print("\n")  # espacio entre tablas
# Out:
# 📦 Tienda 1:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas
# 0  Tarjeta de crédito                   8
# 1  Tarjeta de crédito                   4
# ...

# %% [markdown]
# #1. Análisis de facturación

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Calcular ingresos por tienda
ingreso_t1 = tienda["Precio"].sum()
ingreso_t2 = tienda2["Precio"].sum()
ingreso_t3 = tienda3["Precio"].sum()
ingreso_t4 = tienda4["Precio"].sum()

# Creación diccionario ingresos por tienda
ingresos_dict = {
    "Tienda 1": ingreso_t1,
    "Tienda 2": ingreso_t2,
    "Tienda 3": ingreso_t3,
    "Tienda 4": ingreso_t4
}



df_ingresos = pd.DataFrame({
    "Tienda": ingresos_dict.keys(),
    "Ingreso Total (sin formato)": ingresos_dict.values()
})

# Crear nueva columna con un formato más legible
df_ingresos["Ingreso Total"] = df_ingresos["Ingreso Total (sin formato)"].apply(lambda x: f"${x:,.2f}")

# Mostrar tabla de ingresos
display(df_ingresos[["Tienda", "Ingreso Total"]])


#Gráfico de torta
plt.figure(figsize=(8, 8))
plt.pie(
    df_ingresos["Ingreso Total (sin formato)"],
    labels=df_ingresos["Tienda"],
    autopct='%1.1f%%',
    startangle=140,
    colors=sns.color_palette('rocket', n_colors=len(df_ingresos))
)
plt.title("Ingresos por Tienda")
plt.tight_layout()
plt.show()
# Out:
#      Tienda      Ingreso Total
# 0  Tienda 1  $1,150,880,400.00
# 1  Tienda 2  $1,116,343,500.00
# 2  Tienda 3  $1,098,019,600.00
# 3  Tienda 4  $1,038,375,700.00

# %%
# Agregar columna 'Tienda' en cada DataFrame
tienda['Tienda'] = 'Tienda 1'
tienda2['Tienda'] = 'Tienda 2'
tienda3['Tienda'] = 'Tienda 3'
tienda4['Tienda'] = 'Tienda 4'

# Combinar
datos_tiendas = pd.concat([tienda, tienda2, tienda3, tienda4], ignore_index=True)


# Asegurarse de que la fecha esté bien convertida
datos_tiendas['Fecha de Compra'] = pd.to_datetime(datos_tiendas['Fecha de Compra'], dayfirst=True)

# Crear columna "Mes"
datos_tiendas['Mes'] = datos_tiendas['Fecha de Compra'].dt.to_period('M').astype(str)

# Calcular ingresos por fila
datos_tiendas['Ingreso'] = datos_tiendas['Precio'] + datos_tiendas['Costo de envío']

# Agrupar ingresos por Mes y Tienda
ingresos_por_tienda = datos_tiendas.groupby(['Mes', 'Tienda'])['Ingreso'].sum().reset_index()

# Gráfico de líneas por tienda
plt.figure(figsize=(14, 7))
sns.lineplot(
    data=ingresos_por_tienda,
    x='Mes',
    y='Ingreso',
    hue='Tienda',  # <- cambiamos esto
    marker='o',
    palette='rocket'
)
plt.xticks(rotation=45)
plt.title('Ingresos Totales por Tienda (Mes a Mes)')
plt.xlabel('Mes')
plt.ylabel('Ingresos ($)')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2. Ventas por categoría

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 1. Agregar columna 'tienda' a cada DataFrame individual
tienda["tienda"] = "Tienda_1"
tienda2["tienda"] = "Tienda_2"
tienda3["tienda"] = "Tienda_3"
tienda4["tienda"] = "Tienda_4"

# 2. Combinar DataFrames
datos_tiendas = pd.concat([tienda, tienda2, tienda3, tienda4], ignore_index=True)

# 3. Limpiar nombres columnas (minúsculas y guiones bajos)
datos_tiendas.columns = datos_tiendas.columns.str.strip().str.lower().str.replace(" ", "_")

# 4. Eliminar columnas duplicadas, dejando solo una 'tienda'
datos_tiendas = datos_tiendas.loc[:, ~datos_tiendas.columns.duplicated()]

# 5. Forzar columnas a string simple para evitar problemas
datos_tiendas['tienda'] = datos_tiendas['tienda'].astype(str)
datos_tiendas['categoría_del_producto'] = datos_tiendas['categoría_del_producto'].astype(str)

# 6. Agrupar por tienda y categoría, contando ventas
ventas_por_categoria = datos_tiendas.groupby(['tienda', 'categoría_del_producto']).size().reset_index(name='cantidad_ventas')

# 7. Ordenar globalmente por cantidad de ventas y tomar top 10 filas
top_10_global = ventas_por_categoria.sort_values('cantidad_ventas', ascending=False).head(10).reset_index(drop=True)

# Mostrar tabla sin índice
display(top_10_global.style.hide(axis="index"))

# Gráfico de barras horizontales ordenado
plt.figure(figsize=(10, 6))
sns.barplot(
    data=top_10_global,
    y='categoría_del_producto',
    x='cantidad_ventas',
    hue='tienda',
    dodge=True,
    palette='rocket'
)
plt.title('Top 10 Categorías Más Vendidas')
plt.xlabel('Cantidad de Ventas')
plt.ylabel('Categoría del Producto')
plt.legend(title='Tienda')
plt.tight_layout()
plt.show()
# Out:
# <style type="text/css">
# </style>
# <table id="T_e96b7" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_e96b7_level0_col0" class="col_heading level0 col0" >tienda</th>
#       <th id="T_e96b7_level0_col1" class="col_heading level0 col1" >categoría_del_producto</th>
#       <th id="T_e96b7_level0_col2" class="col_heading level0 col2" >cantidad_ventas</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e96b7_row0_col0" class="data row0 col0" >Tienda 3</td>
#       <td id="T_e96b7_row0_col1" class="data row0 col1" >Muebles</td>
#       <td id="T_e96b7_row0_col2" class="data row0 col2" >499</td>
#     </tr>
#     <tr>
#       <td id="T_e96b7_row1_col0" class="data row1 col0" >Tienda 4</td>
#       <td id="T_e96b7_row1_col1" class="data row1 col1" >Muebles</td>
#       <td id="T_e96b7_row1_col2" class="data row1 col2" >480</td>
#     </tr>
#     <tr>
#       <td id="T_e96b7_row2_col0" class="data row2 col0" >Tienda 1</td>
# ...

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
# Calcular el promedio de calificación por tienda
calificaciones_promedio = (
    datos_tiendas
    .groupby("tienda")["calificación"]
    .mean()
    .reset_index(name="calificación_promedio")
    .sort_values("calificación_promedio", ascending=False)
)

#  Formatear el promedio con 2 decimales
calificaciones_promedio["calificación_promedio"] = calificaciones_promedio["calificación_promedio"].round(2)

# Mostrar resultado
display(calificaciones_promedio)
# Out:
#      tienda  calificación_promedio
# 2  Tienda 3                   4.05
# 1  Tienda 2                   4.04
# 3  Tienda 4                   4.00
# 0  Tienda 1                   3.98

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
# Agregamos columna 'Tienda' a cada DataFrame antes de concatenar
tienda['Tienda'] = 'Tienda 1'
tienda2['Tienda'] = 'Tienda 2'
tienda3['Tienda'] = 'Tienda 3'
tienda4['Tienda'] = 'Tienda 4'

# Concatenamos los 4 DataFrames en uno solo
df = pd.concat([tienda, tienda2, tienda3, tienda4], ignore_index=True)

# Confirmamos que tenemos las 4 tiendas
print(df['Tienda'].unique())


# Asumimos que cada fila representa 1 unidad vendida
df['Unidades'] = 1

# Agrupamos por tienda y producto, contando unidades vendidas
ventas = df.groupby(['Tienda', 'Producto'])['Unidades'].sum().reset_index()

# Producto más vendido por tienda
top = ventas.loc[ventas.groupby('Tienda')['Unidades'].idxmax()]
top['Tipo'] = 'Más vendidos'

# Producto menos vendido por tienda
bottom = ventas.loc[ventas.groupby('Tienda')['Unidades'].idxmin()]
bottom['Tipo'] = 'Menos vendidos'

# Unimos ambos en un solo DataFrame
resumen = pd.concat([top, bottom])
# Out:
# ['Tienda 1' 'Tienda 2' 'Tienda 3' 'Tienda 4']

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
ax = sns.barplot(data=resumen, x='Tienda', y='Unidades', hue='Tipo', palette='coolwarm')

# Añadir etiquetas con el nombre del producto
for bar, (_, fila) in zip(ax.patches, resumen.iterrows()):
    x = bar.get_x() + bar.get_width() / 2
    y = bar.get_height()
    producto = fila['Producto']

    ax.text(
        x,
        y + 1,  # ligeramente por encima
        producto,
        ha='center',
        va='bottom',
        fontsize=8,
        rotation=45
    )

plt.title('Productos más y menos vendidos por tienda')
plt.xlabel('Tienda')
plt.ylabel('Unidades vendidas')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
promedio_envio = df.groupby('Tienda')['Costo de envío'].mean().reset_index()
promedio_envio.columns = ['Tienda', 'Costo de Envío Promedio']

import seaborn as sns
import matplotlib.pyplot as plt


colores = sns.color_palette("rocket", n_colors=len(promedio_envio))

plt.figure(figsize=(12, 6))
sns.barplot(
    data=promedio_envio,
    x='Tienda',
    y='Costo de Envío Promedio',
    palette=colores,
    hue='Tienda',
    legend=False
)
plt.xticks(rotation=45)
plt.title('Costo de Envío Promedio por Tienda', fontsize=14)
plt.xlabel('Tienda')
plt.ylabel('Costo Promedio de Envío ($)')
plt.tight_layout()
plt.show()

# %%
tabla_final = promedio_envio.sort_values(by='Costo de Envío Promedio', ascending=True)

display(tabla_final.style.format({'Costo de Envío Promedio': '${:,.2f}'}))
# Out:
# <style type="text/css">
# </style>
# <table id="T_8acce" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8acce_level0_col0" class="col_heading level0 col0" >Tienda</th>
#       <th id="T_8acce_level0_col1" class="col_heading level0 col1" >Costo de Envío Promedio</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8acce_level0_row0" class="row_heading level0 row0" >3</th>
#       <td id="T_8acce_row0_col0" class="data row0 col0" >Tienda 4</td>
#       <td id="T_8acce_row0_col1" class="data row0 col1" >$23,459.46</td>
#     </tr>
#     <tr>
#       <th id="T_8acce_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_8acce_row1_col0" class="data row1 col0" >Tienda 3</td>
#       <td id="T_8acce_row1_col1" class="data row1 col1" >$24,805.68</td>
#     </tr>
#     <tr>
#       <th id="T_8acce_level0_row2" class="row_heading level0 row2" >1</th>
# ...

# %% [markdown]
# ## Informe final
#
# #Introducción#
#
# Este informe tiene como objetivo recomendar al Sr. Juan cuál de las cuatro tiendas disponibles representa la mejor oportunidad para comercializar sus productos. Para ello, se realizó un análisis comparativo de cada tienda en función de:
#
# •	Ingresos totales
# •	Categorías de productos más y menos vendidos
# •	Calificación promedio de los clientes
# •	Productos más y menos vendidos
# •	Coste de envío promedio
#
# Con esta información perfectamente volcada. Podrá tomar una decisión estratégica basada en datos objetivos.
#
# #Ingresos totales de las tiendas.
#
# La tienda 1 es la que tiene mejor facturación: $1.150.880.400
# Seguida por la tienda 2 ($1.116.343.500), 3 ($1.098.019.600) y 4 respectivamente ($1.038.375.700).
#
# #Categorías de productos más y menos vendidas.
#
# Los muebles son los productos más vendidos en las tiendas 3 (499 ventas), 4 (480) y 1 (465). El otro rubro más competitivo es el de productos electrónicos con 451 ventas concretadas en las tiendas 4 y 3; y 1 (448) respectivamente.
# El análisis de ventas por categoría muestra dos rubros claramente dominantes: muebles y electrónica. Estas categorías presentan alta rotación, lo que las vuelve atractivas para introducir nuevos productos.
#
# #Calificaciones promedio de los clientes por tienda.
#
# La tienda 3 es la mejor calificada por los clientes (4.05) seguido por la tienda 2 (4.04), la tienda 4 (4.00) y la tienda 1 (3.98)
#
# #Los productos más y menos vendidos.
# Los productos más vendidos en la tienda 1 son los armarios y los menos vendidos los auriculares con micrófonos. Para la tienda 2 son iniciando en programación y los menos vendidos los juegos de mesa. En el caso de la tienda 3 kit de bancas y los bloques de construcción como los menos vendidos. Por último, en la tienda 4, cama box versus guitarra eléctrica como el ítem menos vendido.
#
# #El coste de envío promedio para cada tienda.
#
# Es más conveniente realizar los envíos desde la tienda 4 ($23,459.46), luego desde la tienda 3 ($24,805.68), tienda 2 ($25,216.24) y por último la tienda 1 ($26,018.61).
#
#
# #Conclusión
# Aunque la Tienda 1 lidera en ingresos, este liderazgo no es tan marcado y se ve compensado por otras debilidades como el coste de envío más alto y la calificación más baja por parte de los clientes.
# Por otro lado, la Tienda 4 demuestra una combinación sólida de ventajas competitivas:
# •	Coste de envío más bajo
# •	Buen volumen de ventas en categorías clave
# •	Diversidad de productos vendidos
# •	Calificación aceptable por parte de los usuarios
# Por lo tanto, se recomienda al Sr. Juan que comercialice sus productos en la Tienda 4. Esta tienda ofrece una excelente relación entre eficiencia logística, demanda de productos y amplitud de categorías, con una estructura de costos que favorece tanto al vendedor como al consumidor.
